# %% [markdown]
# # SHSAT Test Results Merge Notebook
# [Return to project overview](final_project_overview.ipynb)
#
# ### Andrew Larimer, Deepak Nagaraj, Daniel Olmstead, Michael Winton (W207-4-Summer 2018 Final Project)
#
# In this notebook, we will merge the data cleaned by the other "prep_" notebooks to create a single merged csv.

# %% [markdown]
# ## Importing dataframes, indexed by our primary key
# While school names may change or be input inconsistently, each school has a unique identifying DBN, sometimes referred to as a Location Code, to identify it. By importing each cleaned dataset with the DBN as the index, we are able to easily join them into a merged dataset.

# %%
import pandas as pd
import datetime
import re

# set default options
pd.set_option('display.max_columns', None)

# %%
# Load all datasets from CSV; when loading set index to the DBN column (to enforce uniqueness)
shsat_df = pd.read_csv('data_cleaned/cleaned_shsat_outcomes.csv', index_col="dbn")
print('SHSAT dataset:',shsat_df.shape) # confirm that it's (589, 5)

class_sizes_df = pd.read_csv('data_cleaned/cleaned_class_sizes.csv', index_col="dbn")
print('Class size dataset:', class_sizes_df.shape) # confirm that it's (494, 13)

explorer_df = pd.read_csv('data_cleaned/cleaned_explorer.csv', index_col="dbn")
print('Explorer dataset:', explorer_df.shape) # confirm that it's (596, 55)

selectiveness_df = pd.read_csv('data_cleaned/selectiveness.csv', index_col='dbn')
print('Selectiveness dataset:', selectiveness_df.shape) # confirm that it's (589, 2)
# Out:
# SHSAT dataset: (589, 5)
# Class size dataset: (494, 13)
# Explorer dataset: (596, 55)
# Selectiveness dataset: (589, 2)

# %% [markdown]
# ## Checking for duplicate entries.
# We do a quick check to make sure there are no duplicate entries.

# %%
shsat_dups = shsat_df.index.duplicated()
class_sizes_dups = class_sizes_df.index.duplicated()
explorer_dups = explorer_df.index.duplicated()
selectiveness_dups = selectiveness_df.index.duplicated()

print("True or False: there are duplicated indices within any dataframes?")
print("{0}.".format(bool(sum(shsat_dups) + sum(class_sizes_dups) + sum(explorer_dups) + 
                         sum(selectiveness_dups))))
# Out:
# True or False: there are duplicated indices within any dataframes?
# False.

# %% [markdown]
# ## Inner joins for more complete data
# We'll use inner joins to select the intersection of our datasets, thus only selecting for schools for which we have data from each dataframe.

# %%
merged_df = shsat_df.join(explorer_df, how="inner")
merged_df = merged_df.join(class_sizes_df, how="inner")
merged_df = merged_df.join(selectiveness_df, how="inner")
print("Merged Dataframe shape:",merged_df.shape)
# Out:
# Merged Dataframe shape: (464, 75)

# %%
merged_df.head()
# Out:
#         grade_7_enrollment  num_shsat_test_takers  offers_per_student  \
# dbn
# 20K187                 266                    251                  75
# 21K239                 422                    336                  46
# 03M054                 295                    257                  53
# 15K051                 379                    280                  33
# 02M312                 177                    163                  62
#
#         pct_test_takers  high_registrations  \
# dbn
# 20K187               91                   1
# 21K239               78                   1
# 03M054               91                   1
# 15K051               75                   1
# 02M312               90                   1
#
#                                               school_name  district    zip  \
# dbn
# 20K187              THE CHRISTA MCAULIFFE SCHOOL\I.S. 187        20  11219
# 21K239      MARK TWAIN I.S. 239 FOR THE GIFTED & TALENTED        21  11224
# 03M054                    J.H.S. 054 BOOKER T. WASHINGTON         3  10025
# 15K051                          M.S. 51 WILLIAM ALEXANDER        15  11215
# 02M312  NEW YORK CITY LAB MIDDLE SCHOOL FOR COLLABORAT...         2  10011
#
#         community_school  economic_need_index  school_income_estimate  \
# dbn
# 20K187                 0                0.480                     NaN
# 21K239                 0                0.311                     NaN
# 03M054                 0                0.221                     NaN
# 15K051                 0                0.248                     NaN
# 02M312                 0                0.308                     NaN
#
#         percent_ell  percent_asian  percent_black  percent_hispanic  \
# dbn
# 20K187            2             69              1                 6
# 21K239            1             28              7                 5
# 03M054            2              9              8                12
# 15K051            2             12             10                19
# 02M312            1             47              2                 7
#
#         percent_black__hispanic  percent_white  student_attendance_rate  \
# dbn
# 20K187                        7             24                     98.0
# 21K239                       12             54                     96.0
# 03M054                       20             64                     96.0
# 15K051                       29             57                     97.0
# 02M312                       10             34                     98.0
#
#         percent_of_students_chronically_absent  rigorous_instruction_percent  \
# dbn
# 20K187                                     2.0                          92.0
# 21K239                                     7.0                          88.0
# 03M054                                     5.0                          85.0
# 15K051                                     3.0                          87.0
# 02M312                                     2.0                          88.0
#
#         rigorous_instruction_rating  collaborative_teachers_percent  \
# dbn
# 20K187                          4.0                            91.0
# 21K239                          3.0                            89.0
# 03M054                          NaN                            83.0
# 15K051                          4.0                            88.0
# 02M312                          3.0                            91.0
#
#         collaborative_teachers_rating  supportive_environment_percent  \
# dbn
# 20K187                            4.0                            92.0
# 21K239                            4.0                            87.0
# 03M054                            NaN                            87.0
# 15K051                            3.0                            89.0
# 02M312                            4.0                            90.0
#
#         supportive_environment_rating  effective_school_leadership_percent  \
# dbn
# 20K187                            4.0                                 90.0
# 21K239                            3.0                                 86.0
# 03M054                            NaN                                 80.0
# 15K051                            4.0                                 85.0
# 02M312                            4.0                                 83.0
#
#         effective_school_leadership_rating  \
# dbn
# 20K187                                 4.0
# 21K239                                 3.0
# 03M054                                 2.0
# 15K051                                 3.0
# 02M312                                 3.0
#
#         strong_family_community_ties_percent  \
# dbn
# 20K187                                  76.0
# 21K239                                  73.0
# 03M054                                  84.0
# 15K051                                  74.0
# 02M312                                  85.0
#
#         strong_family_community_ties_rating  trust_percent  trust_rating  \
# dbn
# 20K187                                  2.0           93.0           4.0
# 21K239                                  2.0           91.0           3.0
# 03M054                                  3.0           90.0           3.0
# 15K051                                  2.0           90.0           3.0
# 02M312                                  3.0           92.0           3.0
#
#         student_achievement_rating  average_ela_proficiency  \
# dbn
# 20K187                         4.0                     3.83
# 21K239                         3.0                     3.53
# 03M054                         4.0                     3.46
# 15K051                         4.0                     3.50
# 02M312                         4.0                     3.62
#
#         average_math_proficiency  grade_7_ela_all_students_tested  \
# dbn
# 20K187                      4.19                              324
# 21K239                      3.71                              355
# 03M054                      3.70                              250
# 15K051                      3.49                              354
# 02M312                      3.94                              173
#
#         grade_7_ela_4s_all_students  \
# dbn
# 20K187                          226
# 21K239                          175
# 03M054                          135
# 15K051                          186
# 02M312                           85
#
#         grade_7_ela_4s_american_indian_or_alaska_native  \
# dbn
# 20K187                                                0
# 21K239                                                0
# 03M054                                                0
# 15K051                                                0
# 02M312                                                0
#
#         grade_7_ela_4s_black_or_african_american  \
# dbn
# 20K187                                         0
# 21K239                                         5
# 03M054                                         4
# 15K051                                         8
# 02M312                                         0
#
#         grade_7_ela_4s_hispanic_or_latino  \
# dbn
# 20K187                                  0
# 21K239                                  4
# 03M054                                  9
# 15K051                                 12
# 02M312                                  0
#
#         grade_7_ela_4s_asian_or_pacific_islander  grade_7_ela_4s_white  \
# dbn
# 20K187                                       154                    61
# 21K239                                        45                   110
# 03M054                                        16                   101
# 15K051                                        27                   134
# 02M312                                        45                    27
#
#         grade_7_ela_4s_multiracial  grade_7_ela_4s_limited_english_proficient  \
# dbn
# 20K187                           0                                          0
# 21K239                          11                                          0
# 03M054                           0                                          0
# 15K051                           0                                          0
# 02M312                           8                                          0
#
#         grade_7_ela_4s_economically_disadvantaged  \
# dbn
# 20K187                                        121
# 21K239                                         32
# 03M054                                         14
# 15K051                                         13
# 02M312                                         27
#
#         grade_7_math_all_students_tested  grade_7_math_4s_all_students  \
# dbn
# 20K187                               324                           304
# 21K239                               352                           205
# 03M054                               251                           170
# 15K051                               354                           188
# 02M312                               173                           130
#
#         grade_7_math_4s_american_indian_or_alaska_native  \
# dbn
# 20K187                                                 0
# 21K239                                                 0
# 03M054                                                 0
# 15K051                                                 0
# 02M312                                                 0
#
#         grade_7_math_4s_black_or_african_american  \
# dbn
# 20K187                                          0
# 21K239                                          5
# 03M054                                          5
# 15K051                                          5
# 02M312                                          0
#
#         grade_7_math_4s_hispanic_or_latino  \
# dbn
# 20K187                                   0
# 21K239                                   6
# 03M054                                   6
# 15K051                                  10
# 02M312                                   0
#
#         grade_7_math_4s_asian_or_pacific_islander  grade_7_math_4s_white  \
# dbn
# 20K187                                        206                     83
# 21K239                                         64                    119
# 03M054                                         23                    129
# 15K051                                         28                    140
# 02M312                                         74                     41
#
#         grade_7_math_4s_multiracial  \
# dbn
# 20K187                            0
# 21K239                           11
# 03M054                            0
# 15K051                            0
# 02M312                           11
#
#         grade_7_math_4s_limited_english_proficient  \
# dbn
# 20K187                                           0
# 21K239                                           0
# 03M054                                           0
# 15K051                                           0
# 02M312                                           0
#
#         grade_7_math_4s_economically_disadvantaged  sie_provided  in_bronx  \
# dbn
# 20K187                                         166             0         0
# 21K239                                          44             0         0
# 03M054                                          17             0         0
# 15K051                                          15             0         0
# 02M312                                          43             0         0
#
#         in_brooklyn  in_manhattan  in_queens  in_staten  \
# dbn
# 20K187            1             0          0          0
# 21K239            1             0          0          0
# 03M054            0             1          0          0
# 15K051            1             0          0          0
# 02M312            0             1          0          0
#
#         number_of_students_english  number_of_students_math  \
# dbn
# 20K187                      1052.0                    934.0
# 21K239                      2710.0                   2164.0
# 03M054                       868.0                    849.0
# 15K051                      1156.0                    992.0
# 02M312                         NaN                    535.0
#
#         number_of_students_science  number_of_students_social_studies  \
# dbn
# 20K187                      1385.0                             1313.0
# 21K239                      1169.0                             1553.0
# 03M054                       849.0                              849.0
# 15K051                      1125.0                             1092.0
# 02M312                       541.0                                NaN
#
#         number_of_classes_english  number_of_classes_math  \
# dbn
# 20K187                       42.0                    37.0
# 21K239                       87.0                    69.0
# 03M054                       32.0                    30.0
# 15K051                       42.0                    35.0
# 02M312                        NaN                    19.0
#
#         number_of_classes_science  number_of_classes_social_studies  \
# dbn
# 20K187                       49.0                              46.0
# 21K239                       37.0                              50.0
# 03M054                       30.0                              30.0
# 15K051                       39.0                              38.0
# 02M312                       18.0                               NaN
#
#         average_class_size_english  average_class_size_math  \
# dbn
# 20K187                   25.047619                25.243243
# 21K239                   31.149425                31.362319
# 03M054                   27.125000                28.300000
# 15K051                   27.523810                28.342857
# 02M312                         NaN                28.157895
#
#         average_class_size_science  average_class_size_social_studies  \
# dbn
# 20K187                   28.265306                          28.543478
# 21K239                   31.594595                          31.060000
# 03M054                   28.300000                          28.300000
# 15K051                   28.846154                          28.736842
# 02M312                   30.055556                                NaN
#
#         school_pupil_teacher_ratio  gifted  selective
# dbn
# 20K187                        17.6       0          1
# 21K239                        16.5       0          1
# 03M054                        17.2       0          1
# 15K051                        17.2       0          1
# 02M312                        16.0       0          1

# %%
print("Merged DF shape:",merged_df.shape)
# Out:
# Merged DF shape: (464, 75)

# %% [markdown]
# ## Evaluating density
# Let's take a look at how sparse our data is.

# %%
print("Total empty cells:",merged_df.isnull().sum().sum())
print("Percent null: {0:.3f}%".format(100*merged_df.isnull().sum().sum()/(merged_df.shape[0]*merged_df.shape[1])))
# Out:
# Total empty cells: 545
# Percent null: 1.566%

# %% [markdown]
# Let's take a look at our worst offending rows and columns to see if anything stands out enough to be removed:
#
# ### Columns with Nulls

# %%
merged_df.isnull().sum()[merged_df.isnull().sum() > 0]\
    .sort_values(ascending=False)
# Out:
# school_income_estimate                    332
# average_class_size_social_studies          19
# number_of_classes_social_studies           19
# number_of_students_social_studies          19
# supportive_environment_rating              15
# rigorous_instruction_rating                14
# collaborative_teachers_rating              14
# trust_rating                               12
# effective_school_leadership_rating         12
# strong_family_community_ties_rating        12
# student_achievement_rating                 11
# average_class_size_english                 10
# number_of_students_english                 10
# number_of_classes_english                  10
# average_ela_proficiency                     3
# student_attendance_rate                     3
# percent_of_students_chronically_absent      3
# rigorous_instruction_percent                3
# collaborative_teachers_percent              3
# supportive_environment_percent              3
# effective_school_leadership_percent         3
# strong_family_community_ties_percent        3
# trust_percent                               3
# average_math_proficiency                    3
# economic_need_index                         3
# number_of_students_math                     1
# number_of_classes_math                      1
# average_class_size_math                     1
# dtype: int64

# %% [markdown]
# ### Rows with Nulls

# %%
merged_df.isnull().sum(axis=1)[merged_df.isnull().sum(axis=1) > 0]\
    .sort_values(ascending=False)
# Out:
# dbn
# 15K839    22
# 03M291    19
# 28Q358    19
# 06M209    14
# 02M407    10
# 28Q332     8
# 02M177     8
# 02M933     8
# 18K763     8
# 31R028     8
# 01M839     7
# 02M255     7
# 30Q300     7
# 02M413     7
# 17K484     7
# 02M312     7
# 19K404     7
# 02M225     6
# 11X462     4
# 13K265     4
# 07X298     4
# 29Q327     4
# 08X376     4
# 01M332     4
# 08X562     4
# 03M860     4
# 19K678     4
# 03M054     4
# 29Q355     4
# 17K590     3
#           ..
# 13K351     1
# 04M825     1
# 15K464     1
# 19K364     1
# 28Q167     1
# 28Q284     1
# 28Q287     1
# 29Q289     1
# 06M322     1
# 06M324     1
# 21K690     1
# 08X375     1
# 12X318     1
# 10X391     1
# 12X242     1
# 13K691     1
# 18K598     1
# 07X223     1
# 09X361     1
# 10X243     1
# 15K136     1
# 16K267     1
# 17K354     1
# 18K581     1
# 29Q192     1
# 01M378     1
# 08X448     1
# 10X308     1
# 12X190     1
# 20K187     1
# Length: 339, dtype: int64

# %% [markdown]
# At the moment we don't see any of these as being offending enough to be removed, especially since we have already preserved some info from the 'school_income_estimate' feature.

# %% [markdown]
# ## Save a dated file
#
# To allow updates to the merged dataframe without disrupting work on models downstream until they are ready, we save a dated merged filename.

# %%
# Get the date to create the filename.
d = datetime.date
filename = "combined_data_{0}.csv".format( d.today().isoformat() )
print(filename)
# Out:
# combined_data_2018-08-07.csv

# %%
# check final shape (464,69)
merged_df.shape
# Out:
# (464, 75)

# %%
merged_df.to_csv("data_merged/{0}".format(filename))

# %% [markdown]
# ## Save alternate dataset without class size information
# Because we are missing class size data for approximately 100 schools, the `inner join` used to merge our dataframes drops those rows.  We will also save a variant of our dataset without the class size data, in case it turns out those features have low predictve value in our models.

# %%
no_class_size_df = shsat_df.join(explorer_df, how="inner")
no_class_size_df = no_class_size_df.join(selectiveness_df, how="inner")
print("Merged Dataframe shape (without class size data):",no_class_size_df.shape)
# Out:
# Merged Dataframe shape (without class size data): (556, 62)

# %% [markdown]
# ### Verify that characteristics of the dataset (in terms of nulls) are similar to above

# %%
print("Total empty cells:",no_class_size_df.isnull().sum().sum())
print("Percent null: {0:.3f}%".format(100*no_class_size_df.isnull().sum().sum()/
                                      (no_class_size_df.shape[0]*no_class_size_df.shape[1])))

# check columns with nulls
no_class_size_df.isnull().sum()[no_class_size_df.isnull().sum() > 0]\
    .sort_values(ascending=False)
# Out:
# Total empty cells: 574
# Percent null: 1.665%
# school_income_estimate                    371
# supportive_environment_rating              26
# rigorous_instruction_rating                22
# collaborative_teachers_rating              22
# trust_rating                               21
# strong_family_community_ties_rating        21
# effective_school_leadership_rating         20
# student_achievement_rating                 16
# collaborative_teachers_percent              5
# student_attendance_rate                     5
# percent_of_students_chronically_absent      5
# rigorous_instruction_percent                5
# average_math_proficiency                    5
# supportive_environment_percent              5
# average_ela_proficiency                     5
# effective_school_leadership_percent         5
# strong_family_community_ties_percent        5
# trust_percent                               5
# economic_need_index                         5
# dtype: int64

# %% [markdown]
# There characteristics are similar to our primary dataset, so we should feel comfortable using it if we do not need the class size data in our models.  Note that several of the columns with nulls in our primary merged dataset originally came from the class size data.  As a result, aside from `school_income_estimate`, our columns look quite good with respect to nulls.

# %%
# Get the date to create the filename.
filename = "combined_data_no_class_sizes_{0}.csv".format( d.today().isoformat() )
print(filename)

# check final shape (556, 62)
print(no_class_size_df.shape)

no_class_size_df.to_csv("data_merged/{0}".format(filename))
# Out:
# combined_data_no_class_sizes_2018-08-07.csv
# (556, 62)
